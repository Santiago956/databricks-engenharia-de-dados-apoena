# %%
# %fs ls dbfs:/databricks-datasets/

# %%
# %sql
SELECT *
FROM PARQUET.`dbfs:/databricks-datasets/learning-spark-v2/sf-airbnb/sf-airbnb-clean.parquet/`

# %%
# %fs head dbfs:/databricks-datasets/learning-spark/data-001/pandainfo.json

# %%
# %sql
SELECT * FROM JSON.`dbfs:/databricks-datasets/learning-spark/data-001/pandainfo.json`

# %%
# %sql
SELECT * FROM TEXT.`dbfs:/databricks-datasets/learning-spark/data-001/pandainfo.json`

# %%
# %sql
SELECT _metadata.file_path, * FROM JSON.`dbfs:/databricks-datasets/learning-spark/data-001/pandainfo.json`;
    
SELECT _metadata.file_path, * FROM TEXT.`dbfs:/databricks-datasets/learning-spark/data-001/fake_logs/log*.log`;

# %%
# %sql

SELECT * 
FROM read_files(
    'dbfs:/databricks-datasets/wine-quality/winequality-white.csv',
    format => 'csv',
    delimiter => ';',
    header => true,
    mode => 'PERMISSIVE ',
    inferSchema => true
);
